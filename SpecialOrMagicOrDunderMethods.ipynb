# %%
mylist = [1,2,3]

# %%
len(mylist)
# Out:
# 3

# %%
class Sample():
    pass

# %%
mysample = Sample()

# %%
print(mysample)
# Out:
# <__main__.Sample object at 0x7f98ac76f0e0>

# %%
print(mylist)
# Out:
# [1, 2, 3]

# %%
class Book():
    def __init__(self, title, author, pages):
        
        self.title = title
        self.author = author
        self.pages = pages

# %%
b = Book('Python rocks', 'Jose', 200)

# %%
print(b)
# Out:
# <__main__.Book object at 0x7f3c8d735d30>

# %%
str(b)
# Out:
# '<__main__.Book object at 0x7f3c8d735d30>'

# %%
class Book():
    def __init__(self, title, author, pages):
        
        self.title = title
        self.author = author
        self.pages = pages
        
    def __str__(self):
        return f"{self.title} by {self.author}"
    
    def __len__(self):
        return self.pages
    
    def __del__(self):
        print("A book object has been deleted!")

# %%
b = Book('Python rocks', 'Jose', 200)

# %%
print(b)
# Out:
# Python rocks by Jose

# %%
len(b)
# Out:
# 200

# %%
del b
# Out:
# A book object has been deleted!

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 b
#
# NameError: name 'b' is not defined
